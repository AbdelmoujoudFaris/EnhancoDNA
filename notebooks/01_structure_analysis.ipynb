# %% [markdown]
# # 01 - Structure Analysis
#
# Load a structure, classify chains, and inspect protein-DNA contacts.

# %%
import sys; sys.path.insert(0, "../src")
from enhancoai.structure.parser import load_structure
from enhancoai.structure.chain_detection import summarize_chains

structure = load_structure("../data/examples/demo_tf_dna_two_factor.pdb")
summarize_chains(structure)

# %%
from enhancoai.interactions.protein_dna import analyse_protein_dna_interactions

result = analyse_protein_dna_interactions(structure, "A", "C")
result.summary()
