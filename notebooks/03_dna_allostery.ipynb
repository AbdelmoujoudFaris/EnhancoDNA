# %% [markdown]
# # 03 - DNA Geometry and Allostery
#
# Simplified base-pair-step parameters and a communication-network sketch.

# %%
import sys; sys.path.insert(0, "../src")
from enhancoai.structure.parser import load_structure
from enhancoai.dna.geometry import find_watson_crick_pairs, base_pair_frames
from enhancoai.dna.helical_parameters import step_parameters

structure = load_structure("../data/examples/demo_tf_dna_two_factor.pdb")
pairs = find_watson_crick_pairs(structure, "C", "D")
frames = base_pair_frames(structure, "C", "D", pairs)
step_parameters(frames)
