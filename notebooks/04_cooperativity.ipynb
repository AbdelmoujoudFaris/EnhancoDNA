# %% [markdown]
# # 04 - Cooperativity
#
# PMF, binding free energy, and the composite Cooperativity Score.

# %%
import sys; sys.path.insert(0, "../src")
import numpy as np
from enhancoai.free_energy.pmf import compute_pmf_1d
from enhancoai.free_energy.cooperativity import cooperativity_free_energy

rng = np.random.default_rng(0)
pmf_a = compute_pmf_1d(rng.normal(15, 3, 1000))
pmf_ab = compute_pmf_1d(rng.normal(9, 2, 1000))
cooperativity_free_energy(pmf_a, pmf_ab)
